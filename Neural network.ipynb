# %% [markdown]
# #

# %% [markdown]
# # Neural Network TensorFlow

# %%
seed_value= 0
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import pandas as pd
import tensorflow as tf
tf.random.set_seed(seed_value)
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('dividendinfo.csv')

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#data =pd.read_csv('/content/drive/Othercomputers/My MacBook Air/Data-Analysis/Neural network/dividendinfo.csv')

# %% [markdown]
# # Data Normalization

# %%
data_norm = (data - data.min()) / (data.max() - data.min())
X=data_norm.drop(['dividend'],axis=1)
y=data_norm.dividend

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# # Deep Neural Network

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(3, input_shape=(5,), activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=15, batch_size=5)
# Out:
# Epoch 1/15
# 32/32 [==============================] - 0s 478us/step - loss: 0.6802 - accuracy: 0.5750
# Epoch 2/15
# 32/32 [==============================] - 0s 395us/step - loss: 0.6769 - accuracy: 0.6313
# Epoch 3/15
# 32/32 [==============================] - 0s 415us/step - loss: 0.6731 - accuracy: 0.6750
# Epoch 4/15
# 32/32 [==============================] - 0s 368us/step - loss: 0.6697 - accuracy: 0.6875
# Epoch 5/15
# 32/32 [==============================] - 0s 389us/step - loss: 0.6658 - accuracy: 0.6875
# Epoch 6/15
# 32/32 [==============================] - 0s 389us/step - loss: 0.6612 - accuracy: 0.6938
# Epoch 7/15
# 32/32 [==============================] - 0s 379us/step - loss: 0.6576 - accuracy: 0.6938
# Epoch 8/15
# 32/32 [==============================] - 0s 378us/step - loss: 0.6520 - accuracy: 0.7063
# Epoch 9/15
# 32/32 [==============================] - 0s 371us/step - loss: 0.6472 - accuracy: 0.7125
# Epoch 10/15
# ...

# %%
print(model.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_43 (Dense)            (None, 3)                 18
#
#  dense_44 (Dense)            (None, 2)                 8
#
#  dense_45 (Dense)            (None, 1)                 3
#
# ...
# Total params: 29
# Trainable params: 29
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from sklearn.metrics import confusion_matrix
predictions = model.predict(X_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
confusion_matrix = confusion_matrix(y_test, rounded) 
print(confusion_matrix)
# Out:
# 2/2 [==============================] - 0s 2ms/step
# [[16  1]
#  [ 7 16]]

# %%
from sklearn.metrics import classification_report


print(classification_report(y_test,rounded))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.94      0.80        17
#          1.0       0.94      0.70      0.80        23
#
#     accuracy                           0.80        40
#    macro avg       0.82      0.82      0.80        40
# weighted avg       0.84      0.80      0.80        40

# %%
accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy[1]*100))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x29256e320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5905 - accuracy: 0.8000
# Accuracy: 80.00

# %%
from ann_visualizer.visualize import ann_viz

ann_viz(model, filename='output', title="My first neural network")

# %% [markdown]
# ![title](output.png)

# %% [markdown]
# # Deeper Neural Networks

# %%
model_2 = tf.keras.models.Sequential([
  tf.keras.layers.Dense(7, input_shape=(5,), activation='relu'),
  tf.keras.layers.Dense(5, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_2.fit(X_train, y_train, epochs=15, batch_size=5)
# Out:
# Epoch 1/15
# 32/32 [==============================] - 0s 470us/step - loss: 0.7078 - accuracy: 0.5312
# Epoch 2/15
# 32/32 [==============================] - 0s 445us/step - loss: 0.6949 - accuracy: 0.5312
# Epoch 3/15
# 32/32 [==============================] - 0s 394us/step - loss: 0.6808 - accuracy: 0.5312
# Epoch 4/15
# 32/32 [==============================] - 0s 363us/step - loss: 0.6641 - accuracy: 0.5312
# Epoch 5/15
# 32/32 [==============================] - 0s 364us/step - loss: 0.6454 - accuracy: 0.5750
# Epoch 6/15
# 32/32 [==============================] - 0s 367us/step - loss: 0.6253 - accuracy: 0.6125
# Epoch 7/15
# 32/32 [==============================] - 0s 363us/step - loss: 0.6073 - accuracy: 0.5938
# Epoch 8/15
# 32/32 [==============================] - 0s 362us/step - loss: 0.5892 - accuracy: 0.7063
# Epoch 9/15
# 32/32 [==============================] - 0s 363us/step - loss: 0.5715 - accuracy: 0.7688
# Epoch 10/15
# ...

# %%
print(model_2.summary())
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_46 (Dense)            (None, 7)                 42
#
#  dense_47 (Dense)            (None, 5)                 40
#
#  dense_48 (Dense)            (None, 1)                 6
#
# ...
# Total params: 88
# Trainable params: 88
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
predictions = model_2.predict(X_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
print(classification_report(y_test,rounded))
# Out:
# 2/2 [==============================] - 0s 896us/step
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.88      0.91        17
#          1.0       0.92      0.96      0.94        23
#
#     accuracy                           0.93        40
#    macro avg       0.93      0.92      0.92        40
# weighted avg       0.93      0.93      0.92        40

# %%
ann_viz(model_2, filename='output2',title="My first neural network")

# %% [markdown]
# ![title](output2.png)

# %%
model_3 = tf.keras.models.Sequential([
  tf.keras.layers.Dense(5, input_shape=(5,), activation='relu'),
  tf.keras.layers.Dense(4, activation='relu'),
  tf.keras.layers.Dense(3, activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(2, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model_3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_3.fit(X_train, y_train, epochs=15, batch_size=5)
# Out:
# Epoch 1/15
# 32/32 [==============================] - 0s 798us/step - loss: 0.6918 - accuracy: 0.5063
# Epoch 2/15
# 32/32 [==============================] - 0s 835us/step - loss: 0.6877 - accuracy: 0.5063
# Epoch 3/15
# 32/32 [==============================] - 0s 594us/step - loss: 0.6827 - accuracy: 0.5063
# Epoch 4/15
# 32/32 [==============================] - 0s 644us/step - loss: 0.6771 - accuracy: 0.5875
# Epoch 5/15
# 32/32 [==============================] - 0s 839us/step - loss: 0.6696 - accuracy: 0.5063
# Epoch 6/15
# 32/32 [==============================] - 0s 832us/step - loss: 0.6623 - accuracy: 0.5063
# Epoch 7/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6515 - accuracy: 0.7312
# Epoch 8/15
# 32/32 [==============================] - 0s 446us/step - loss: 0.6406 - accuracy: 0.7188
# Epoch 9/15
# 32/32 [==============================] - 0s 767us/step - loss: 0.6279 - accuracy: 0.7000
# Epoch 10/15
# ...

# %%
print(model_3.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_49 (Dense)            (None, 5)                 30
#
#  dense_50 (Dense)            (None, 4)                 24
#
#  dense_51 (Dense)            (None, 3)                 15
#
#  dense_52 (Dense)            (None, 2)                 8
#
#  dense_53 (Dense)            (None, 2)                 6
#
#  dense_54 (Dense)            (None, 1)                 3
#
# ...
# Total params: 86
# Trainable params: 86
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
predictions = model_3.predict(X_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
print(classification_report(y_test,rounded))
# Out:
# 2/2 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.74      1.00      0.85        17
#          1.0       1.00      0.74      0.85        23
#
#     accuracy                           0.85        40
#    macro avg       0.87      0.87      0.85        40
# weighted avg       0.89      0.85      0.85        40

# %%
ann_viz(model_3, filename='output3',title="My first neural network")

# %% [markdown]
# ![title](output3.png)
